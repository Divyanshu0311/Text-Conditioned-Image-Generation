# %%
# !pip install torch
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.3.0+cu121)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.15.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 50.3 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105

# %%
! gdown --id 19puyGgjEqjY8KwIxAiwQmppip4ETjOy3
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:132: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=19puyGgjEqjY8KwIxAiwQmppip4ETjOy3
# From (redirected): https://drive.google.com/uc?id=19puyGgjEqjY8KwIxAiwQmppip4ETjOy3&confirm=t&uuid=30273435-16dc-443c-b7a1-681410d9a133
# To: /content/data.zip
# 100% 459M/459M [00:03<00:00, 122MB/s]

# %%
# !unzip data.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: data/train_masks/0789bed99cb8_09_mask.gif
#  extracting: data/train_masks/0789bed99cb8_10_mask.gif
#  extracting: data/train_masks/0789bed99cb8_11_mask.gif
#  extracting: data/train_masks/0789bed99cb8_12_mask.gif
#   inflating: data/train_masks/0789bed99cb8_13_mask.gif
#   inflating: data/train_masks/0789bed99cb8_14_mask.gif
#  extracting: data/train_masks/0789bed99cb8_15_mask.gif
#  extracting: data/train_masks/0789bed99cb8_16_mask.gif
#  extracting: data/train_masks/0795e132d090_01_mask.gif
#  extracting: data/train_masks/0795e132d090_02_mask.gif
#  extracting: data/train_masks/0795e132d090_03_mask.gif
#  extracting: data/train_masks/0795e132d090_04_mask.gif
#  extracting: data/train_masks/0795e132d090_05_mask.gif
#  extracting: data/train_masks/0795e132d090_06_mask.gif
#  extracting: data/train_masks/0795e132d090_07_mask.gif
#  extracting: data/train_masks/0795e132d090_08_mask.gif
#  extracting: data/train_masks/0795e132d090_09_mask.gif
#  extracting: data/train_masks/0795e132d090_10_mask.gif
#  extracting: data/train_masks/0795e132d090_11_mask.gif
#  extracting: data/train_masks/0795e132d090_12_mask.gif
#  extracting: data/train_masks/0795e132d090_13_mask.gif
#  extracting: data/train_masks/0795e132d090_14_mask.gif
#  extracting: data/train_masks/0795e132d090_15_mask.gif
#  extracting: data/train_masks/0795e132d090_16_mask.gif
#  extracting: data/train_masks/08a646be6b30_01_mask.gif
#  extracting: data/train_masks/08a646be6b30_02_mask.gif
#  extracting: data/train_masks/08a646be6b30_03_mask.gif
#  extracting: data/train_masks/08a646be6b30_04_mask.gif
#  extracting: data/train_masks/08a646be6b30_05_mask.gif
#  extracting: data/train_masks/08a646be6b30_06_mask.gif
#  extracting: data/train_masks/08a646be6b30_07_mask.gif
#  extracting: data/train_masks/08a646be6b30_08_mask.gif
#  extracting: data/train_masks/08a646be6b30_09_mask.gif
#  extracting: data/train_masks/08a646be6b30_10_mask.gif
#  extracting: data/train_masks/08a646be6b30_11_mask.gif
#  extracting: data/train_masks/08a646be6b30_12_mask.gif
#  extracting: data/train_masks/08a646be6b30_13_mask.gif
#  extracting: data/train_masks/08a646be6b30_14_mask.gif
#  extracting: data/train_masks/08a646be6b30_15_mask.gif
#  extracting: data/train_masks/08a646be6b30_16_mask.gif
#  extracting: data/train_masks/0cdf5b5d0ce1_01_mask.gif
#  extracting: data/train_masks/0cdf5b5d0ce1_02_mask.gif
#  extracting: data/train_masks/0cdf5b5d0ce1_03_mask.gif
#  extracting: data/train_masks/0cdf5b5d0ce1_04_mask.gif
#  extracting: data/train_masks/0cdf5b5d0ce1_05_mask.gif
#  extracting: data/train_masks/0cdf5b5d0ce1_06_mask.gif
#   inflating: data/train_masks/0cdf5b5d0ce1_07_mask.gif
#  extracting: data/train_masks/0cdf5b5d0ce1_08_mask.gif
#  extracting: data/train_masks/0cdf5b5d0ce1_09_mask.gif
#  extracting: data/train_masks/0cdf5b5d0ce1_10_mask.gif
#   inflating: data/train_masks/0cdf5b5d0ce1_11_mask.gif
#  extracting: data/train_masks/0cdf5b5d0ce1_12_mask.gif
#   inflating: data/train_masks/0cdf5b5d0ce1_13_mask.gif
#  extracting: data/train_masks/0cdf5b5d0ce1_14_mask.gif
#  extracting: data/train_masks/0cdf5b5d0ce1_15_mask.gif
#  extracting: data/train_masks/0cdf5b5d0ce1_16_mask.gif
#  extracting: data/train_masks/0ce66b539f52_01_mask.gif
#  extracting: data/train_masks/0ce66b539f52_02_mask.gif
#  extracting: data/train_masks/0ce66b539f52_03_mask.gif
#   inflating: data/train_masks/0ce66b539f52_04_mask.gif
#  extracting: data/train_masks/0ce66b539f52_05_mask.gif
#   inflating: data/train_masks/0ce66b539f52_06_mask.gif
#  extracting: data/train_masks/0ce66b539f52_07_mask.gif
#  extracting: data/train_masks/0ce66b539f52_08_mask.gif
#   inflating: data/train_masks/0ce66b539f52_09_mask.gif
#  extracting: data/train_masks/0ce66b539f52_10_mask.gif
#   inflating: data/train_masks/0ce66b539f52_11_mask.gif
#  extracting: data/train_masks/0ce66b539f52_12_mask.gif
#   inflating: data/train_masks/0ce66b539f52_13_mask.gif
#  extracting: data/train_masks/0ce66b539f52_14_mask.gif
#  extracting: data/train_masks/0ce66b539f52_15_mask.gif
#  extracting: data/train_masks/0ce66b539f52_16_mask.gif
#  extracting: data/train_masks/0d1a9caf4350_01_mask.gif
#  extracting: data/train_masks/0d1a9caf4350_02_mask.gif
#  extracting: data/train_masks/0d1a9caf4350_03_mask.gif
#  extracting: data/train_masks/0d1a9caf4350_04_mask.gif
#  extracting: data/train_masks/0d1a9caf4350_05_mask.gif
#  extracting: data/train_masks/0d1a9caf4350_06_mask.gif
#  extracting: data/train_masks/0d1a9caf4350_07_mask.gif
#  extracting: data/train_masks/0d1a9caf4350_08_mask.gif
#  extracting: data/train_masks/0d1a9caf4350_09_mask.gif
#  extracting: data/train_masks/0d1a9caf4350_10_mask.gif
#  extracting: data/train_masks/0d1a9caf4350_11_mask.gif
#  extracting: data/train_masks/0d1a9caf4350_12_mask.gif
#  extracting: data/train_masks/0d1a9caf4350_13_mask.gif
#  extracting: data/train_masks/0d1a9caf4350_14_mask.gif
#  extracting: data/train_masks/0d1a9caf4350_15_mask.gif
#  extracting: data/train_masks/0d1a9caf4350_16_mask.gif
#  extracting: data/train_masks/0d3adbbc9a8b_01_mask.gif
#  extracting: data/train_masks/0d3adbbc9a8b_02_mask.gif
#  extracting: data/train_masks/0d3adbbc9a8b_03_mask.gif
#  extracting: data/train_masks/0d3adbbc9a8b_04_mask.gif
#  extracting: data/train_masks/0d3adbbc9a8b_05_mask.gif
#  extracting: data/train_masks/0d3adbbc9a8b_06_mask.gif
#  extracting: data/train_masks/0d3adbbc9a8b_07_mask.gif
#  extracting: data/train_masks/0d3adbbc9a8b_08_mask.gif
#  extracting: data/train_masks/0d3adbbc9a8b_09_mask.gif
#  extracting: data/train_masks/0d3adbbc9a8b_10_mask.gif
#  extracting: data/train_masks/0d3adbbc9a8b_11_mask.gif
#  extracting: data/train_masks/0d3adbbc9a8b_12_mask.gif
#  extracting: data/train_masks/0d3adbbc9a8b_13_mask.gif
#  extracting: data/train_masks/0d3adbbc9a8b_14_mask.gif
#  extracting: data/train_masks/0d3adbbc9a8b_15_mask.gif
#  extracting: data/train_masks/0d3adbbc9a8b_16_mask.gif
#  extracting: data/train_masks/0d53224da2b7_01_mask.gif
#  extracting: data/train_masks/0d53224da2b7_02_mask.gif
#  extracting: data/train_masks/0d53224da2b7_03_mask.gif
#  extracting: data/train_masks/0d53224da2b7_04_mask.gif
#  extracting: data/train_masks/0d53224da2b7_05_mask.gif
#  extracting: data/train_masks/0d53224da2b7_06_mask.gif
#  extracting: data/train_masks/0d53224da2b7_07_mask.gif
#  extracting: data/train_masks/0d53224da2b7_08_mask.gif
#  extracting: data/train_masks/0d53224da2b7_09_mask.gif
#  extracting: data/train_masks/0d53224da2b7_10_mask.gif
#  extracting: data/train_masks/0d53224da2b7_11_mask.gif
#  extracting: data/train_masks/0d53224da2b7_12_mask.gif
#  extracting: data/train_masks/0d53224da2b7_13_mask.gif
#  extracting: data/train_masks/0d53224da2b7_14_mask.gif
#  extracting: data/train_masks/0d53224da2b7_15_mask.gif
#  extracting: data/train_masks/0d53224da2b7_16_mask.gif
#  extracting: data/train_masks/0de66245f268_01_mask.gif
#  extracting: data/train_masks/0de66245f268_02_mask.gif
#  extracting: data/train_masks/0de66245f268_03_mask.gif
#  extracting: data/train_masks/0de66245f268_04_mask.gif
#   inflating: data/train_masks/0de66245f268_05_mask.gif
#   inflating: data/train_masks/0de66245f268_06_mask.gif
#  extracting: data/train_masks/0de66245f268_07_mask.gif
#  extracting: data/train_masks/0de66245f268_08_mask.gif
#  extracting: data/train_masks/0de66245f268_09_mask.gif
#  extracting: data/train_masks/0de66245f268_10_mask.gif
#  extracting: data/train_masks/0de66245f268_11_mask.gif
#  extracting: data/train_masks/0de66245f268_12_mask.gif
#  extracting: data/train_masks/0de66245f268_13_mask.gif
#  extracting: data/train_masks/0de66245f268_14_mask.gif
#  extracting: data/train_masks/0de66245f268_15_mask.gif
#  extracting: data/train_masks/0de66245f268_16_mask.gif
#  extracting: data/train_masks/0ed6904e1004_01_mask.gif
#  extracting: data/train_masks/0ed6904e1004_02_mask.gif
#  extracting: data/train_masks/0ed6904e1004_03_mask.gif
#  extracting: data/train_masks/0ed6904e1004_04_mask.gif
#  extracting: data/train_masks/0ed6904e1004_05_mask.gif
#  extracting: data/train_masks/0ed6904e1004_06_mask.gif
#  extracting: data/train_masks/0ed6904e1004_07_mask.gif
#  extracting: data/train_masks/0ed6904e1004_08_mask.gif
#  extracting: data/train_masks/0ed6904e1004_09_mask.gif
#  extracting: data/train_masks/0ed6904e1004_10_mask.gif
#  extracting: data/train_masks/0ed6904e1004_11_mask.gif
#  extracting: data/train_masks/0ed6904e1004_12_mask.gif
#  extracting: data/train_masks/0ed6904e1004_13_mask.gif
#  extracting: data/train_masks/0ed6904e1004_14_mask.gif
#  extracting: data/train_masks/0ed6904e1004_15_mask.gif
#  extracting: data/train_masks/0ed6904e1004_16_mask.gif
#  extracting: data/train_masks/0ee135a3cccc_01_mask.gif
#  extracting: data/train_masks/0ee135a3cccc_02_mask.gif
#  extracting: data/train_masks/0ee135a3cccc_03_mask.gif
#  extracting: data/train_masks/0ee135a3cccc_04_mask.gif
#   inflating: data/train_masks/0ee135a3cccc_05_mask.gif
#  extracting: data/train_masks/0ee135a3cccc_06_mask.gif
#  extracting: data/train_masks/0ee135a3cccc_07_mask.gif
#  extracting: data/train_masks/0ee135a3cccc_08_mask.gif
#  extracting: data/train_masks/0ee135a3cccc_09_mask.gif
#  extracting: data/train_masks/0ee135a3cccc_10_mask.gif
#  extracting: data/train_masks/0ee135a3cccc_11_mask.gif
#  extracting: data/train_masks/0ee135a3cccc_12_mask.gif
#   inflating: data/train_masks/0ee135a3cccc_13_mask.gif
#  extracting: data/train_masks/0ee135a3cccc_14_mask.gif
#  extracting: data/train_masks/0ee135a3cccc_15_mask.gif
#  extracting: data/train_masks/0ee135a3cccc_16_mask.gif
#  extracting: data/train_masks/0eeaf1ff136d_01_mask.gif
#  extracting: data/train_masks/0eeaf1ff136d_02_mask.gif
#  extracting: data/train_masks/0eeaf1ff136d_03_mask.gif
#  extracting: data/train_masks/0eeaf1ff136d_04_mask.gif
#   inflating: data/train_masks/0eeaf1ff136d_05_mask.gif
#  extracting: data/train_masks/0eeaf1ff136d_06_mask.gif
#  extracting: data/train_masks/0eeaf1ff136d_07_mask.gif
#  extracting: data/train_masks/0eeaf1ff136d_08_mask.gif
#  extracting: data/train_masks/0eeaf1ff136d_09_mask.gif
#  extracting: data/train_masks/0eeaf1ff136d_10_mask.gif
#   inflating: data/train_masks/0eeaf1ff136d_11_mask.gif
#  extracting: data/train_masks/0eeaf1ff136d_12_mask.gif
#  extracting: data/train_masks/0eeaf1ff136d_13_mask.gif
#  extracting: data/train_masks/0eeaf1ff136d_14_mask.gif
#  extracting: data/train_masks/0eeaf1ff136d_15_mask.gif
#  extracting: data/train_masks/0eeaf1ff136d_16_mask.gif
#  extracting: data/train_masks/11acc40dc0ea_01_mask.gif
#  extracting: data/train_masks/11acc40dc0ea_02_mask.gif
#  extracting: data/train_masks/11acc40dc0ea_03_mask.gif
#  extracting: data/train_masks/11acc40dc0ea_04_mask.gif
#  extracting: data/train_masks/11acc40dc0ea_05_mask.gif
#  extracting: data/train_masks/11acc40dc0ea_06_mask.gif
#  extracting: data/train_masks/11acc40dc0ea_07_mask.gif
#  extracting: data/train_masks/11acc40dc0ea_08_mask.gif
#  extracting: data/train_masks/11acc40dc0ea_09_mask.gif
#  extracting: data/train_masks/11acc40dc0ea_10_mask.gif
#  extracting: data/train_masks/11acc40dc0ea_11_mask.gif
#  extracting: data/train_masks/11acc40dc0ea_12_mask.gif
#  extracting: data/train_masks/11acc40dc0ea_13_mask.gif
#  extracting: data/train_masks/11acc40dc0ea_14_mask.gif
#  extracting: data/train_masks/11acc40dc0ea_15_mask.gif
#  extracting: data/train_masks/11acc40dc0ea_16_mask.gif
#   inflating: data/train_masks/11f3dc041cfb_01_mask.gif
#   inflating: data/train_masks/11f3dc041cfb_02_mask.gif
#   inflating: data/train_masks/11f3dc041cfb_03_mask.gif
#   inflating: data/train_masks/11f3dc041cfb_04_mask.gif
#   inflating: data/train_masks/11f3dc041cfb_05_mask.gif
#   inflating: data/train_masks/11f3dc041cfb_06_mask.gif
#   inflating: data/train_masks/11f3dc041cfb_07_mask.gif
#   inflating: data/train_masks/11f3dc041cfb_08_mask.gif
#   inflating: data/train_masks/11f3dc041cfb_09_mask.gif
#   inflating: data/train_masks/11f3dc041cfb_10_mask.gif
#   inflating: data/train_masks/11f3dc041cfb_11_mask.gif
#   inflating: data/train_masks/11f3dc041cfb_12_mask.gif
#   inflating: data/train_masks/11f3dc041cfb_13_mask.gif
#   inflating: data/train_masks/11f3dc041cfb_14_mask.gif
#   inflating: data/train_masks/11f3dc041cfb_15_mask.gif
#   inflating: data/train_masks/11f3dc041cfb_16_mask.gif
#  extracting: data/train_masks/11fcda0a9e1c_01_mask.gif
#  extracting: data/train_masks/11fcda0a9e1c_02_mask.gif
#  extracting: data/train_masks/11fcda0a9e1c_03_mask.gif
#  extracting: data/train_masks/11fcda0a9e1c_04_mask.gif
#  extracting: data/train_masks/11fcda0a9e1c_05_mask.gif
#  extracting: data/train_masks/11fcda0a9e1c_06_mask.gif
#  extracting: data/train_masks/11fcda0a9e1c_07_mask.gif
#  extracting: data/train_masks/11fcda0a9e1c_08_mask.gif
#  extracting: data/train_masks/11fcda0a9e1c_09_mask.gif
#  extracting: data/train_masks/11fcda0a9e1c_10_mask.gif
#  extracting: data/train_masks/11fcda0a9e1c_11_mask.gif
#  extracting: data/train_masks/11fcda0a9e1c_12_mask.gif
#  extracting: data/train_masks/11fcda0a9e1c_13_mask.gif
#  extracting: data/train_masks/11fcda0a9e1c_14_mask.gif
#  extracting: data/train_masks/11fcda0a9e1c_15_mask.gif
#  extracting: data/train_masks/11fcda0a9e1c_16_mask.gif
#   inflating: data/train_masks/120c1dc7b116_01_mask.gif
#   inflating: data/train_masks/120c1dc7b116_02_mask.gif
#   inflating: data/train_masks/120c1dc7b116_03_mask.gif
#   inflating: data/train_masks/120c1dc7b116_04_mask.gif
#   inflating: data/train_masks/120c1dc7b116_05_mask.gif
#   inflating: data/train_masks/120c1dc7b116_06_mask.gif
#   inflating: data/train_masks/120c1dc7b116_07_mask.gif
#   inflating: data/train_masks/120c1dc7b116_08_mask.gif
#   inflating: data/train_masks/120c1dc7b116_09_mask.gif
#   inflating: data/train_masks/120c1dc7b116_10_mask.gif
#   inflating: data/train_masks/120c1dc7b116_11_mask.gif
#   inflating: data/train_masks/120c1dc7b116_12_mask.gif
#   inflating: data/train_masks/120c1dc7b116_13_mask.gif
#   inflating: data/train_masks/120c1dc7b116_14_mask.gif
#   inflating: data/train_masks/120c1dc7b116_15_mask.gif
#   inflating: data/train_masks/120c1dc7b116_16_mask.gif
#  extracting: data/train_masks/1258cf954183_01_mask.gif
#  extracting: data/train_masks/1258cf954183_02_mask.gif
#  extracting: data/train_masks/1258cf954183_03_mask.gif
#  extracting: data/train_masks/1258cf954183_04_mask.gif
#  extracting: data/train_masks/1258cf954183_05_mask.gif
#  extracting: data/train_masks/1258cf954183_06_mask.gif
#  extracting: data/train_masks/1258cf954183_07_mask.gif
#  extracting: data/train_masks/1258cf954183_08_mask.gif
#  extracting: data/train_masks/1258cf954183_09_mask.gif
#  extracting: data/train_masks/1258cf954183_10_mask.gif
#  extracting: data/train_masks/1258cf954183_11_mask.gif
#  extracting: data/train_masks/1258cf954183_12_mask.gif
#   inflating: data/train_masks/1258cf954183_13_mask.gif
#  extracting: data/train_masks/1258cf954183_14_mask.gif
#  extracting: data/train_masks/1258cf954183_15_mask.gif
#  extracting: data/train_masks/1258cf954183_16_mask.gif
#  extracting: data/train_masks/125cadcb9feb_01_mask.gif
#  extracting: data/train_masks/125cadcb9feb_02_mask.gif
#  extracting: data/train_masks/125cadcb9feb_03_mask.gif
#  extracting: data/train_masks/125cadcb9feb_04_mask.gif
#   inflating: data/train_masks/125cadcb9feb_05_mask.gif
#  extracting: data/train_masks/125cadcb9feb_06_mask.gif
#  extracting: data/train_masks/125cadcb9feb_07_mask.gif
#  extracting: data/train_masks/125cadcb9feb_08_mask.gif
#  extracting: data/train_masks/125cadcb9feb_09_mask.gif
#  extracting: data/train_masks/125cadcb9feb_10_mask.gif
#  extracting: data/train_masks/125cadcb9feb_11_mask.gif
#  extracting: data/train_masks/125cadcb9feb_12_mask.gif
#   inflating: data/train_masks/125cadcb9feb_13_mask.gif
#  extracting: data/train_masks/125cadcb9feb_14_mask.gif
#  extracting: data/train_masks/125cadcb9feb_15_mask.gif
#  extracting: data/train_masks/125cadcb9feb_16_mask.gif
#  extracting: data/train_masks/1390696b70b6_01_mask.gif
#  extracting: data/train_masks/1390696b70b6_02_mask.gif
#  extracting: data/train_masks/1390696b70b6_03_mask.gif
#  extracting: data/train_masks/1390696b70b6_04_mask.gif
#  extracting: data/train_masks/1390696b70b6_05_mask.gif
#  extracting: data/train_masks/1390696b70b6_06_mask.gif
#  extracting: data/train_masks/1390696b70b6_07_mask.gif
#  extracting: data/train_masks/1390696b70b6_08_mask.gif
#  extracting: data/train_masks/1390696b70b6_09_mask.gif
#  extracting: data/train_masks/1390696b70b6_10_mask.gif
#  extracting: data/train_masks/1390696b70b6_11_mask.gif
#  extracting: data/train_masks/1390696b70b6_12_mask.gif
#  extracting: data/train_masks/1390696b70b6_13_mask.gif
#  extracting: data/train_masks/1390696b70b6_14_mask.gif
#  extracting: data/train_masks/1390696b70b6_15_mask.gif
#  extracting: data/train_masks/1390696b70b6_16_mask.gif
#  extracting: data/train_masks/13cad6eeabe8_01_mask.gif
#  extracting: data/train_masks/13cad6eeabe8_02_mask.gif
#  extracting: data/train_masks/13cad6eeabe8_03_mask.gif
#  extracting: data/train_masks/13cad6eeabe8_04_mask.gif
#  extracting: data/train_masks/13cad6eeabe8_05_mask.gif
#  extracting: data/train_masks/13cad6eeabe8_06_mask.gif
#  extracting: data/train_masks/13cad6eeabe8_07_mask.gif
#  extracting: data/train_masks/13cad6eeabe8_08_mask.gif
#  extracting: data/train_masks/13cad6eeabe8_09_mask.gif
#  extracting: data/train_masks/13cad6eeabe8_10_mask.gif
#  extracting: data/train_masks/13cad6eeabe8_11_mask.gif
#  extracting: data/train_masks/13cad6eeabe8_12_mask.gif
#  extracting: data/train_masks/13cad6eeabe8_13_mask.gif
#  extracting: data/train_masks/13cad6eeabe8_14_mask.gif
#  extracting: data/train_masks/13cad6eeabe8_15_mask.gif
#  extracting: data/train_masks/13cad6eeabe8_16_mask.gif
#  extracting: data/train_masks/151c7f2d4183_01_mask.gif
#  extracting: data/train_masks/151c7f2d4183_02_mask.gif
#   inflating: data/train_masks/151c7f2d4183_03_mask.gif
#   inflating: data/train_masks/151c7f2d4183_04_mask.gif
#   inflating: data/train_masks/151c7f2d4183_05_mask.gif
#  extracting: data/train_masks/151c7f2d4183_06_mask.gif
#  extracting: data/train_masks/151c7f2d4183_07_mask.gif
#   inflating: data/train_masks/151c7f2d4183_08_mask.gif
#   inflating: data/train_masks/151c7f2d4183_09_mask.gif
#  extracting: data/train_masks/151c7f2d4183_10_mask.gif
#   inflating: data/train_masks/151c7f2d4183_11_mask.gif
#  extracting: data/train_masks/151c7f2d4183_12_mask.gif
#   inflating: data/train_masks/151c7f2d4183_13_mask.gif
#  extracting: data/train_masks/151c7f2d4183_14_mask.gif
#   inflating: data/train_masks/151c7f2d4183_15_mask.gif
#  extracting: data/train_masks/151c7f2d4183_16_mask.gif
#  extracting: data/train_masks/154ee2b6d27a_01_mask.gif
#  extracting: data/train_masks/154ee2b6d27a_02_mask.gif
#  extracting: data/train_masks/154ee2b6d27a_03_mask.gif
#  extracting: data/train_masks/154ee2b6d27a_04_mask.gif
#  extracting: data/train_masks/154ee2b6d27a_05_mask.gif
#  extracting: data/train_masks/154ee2b6d27a_06_mask.gif
#  extracting: data/train_masks/154ee2b6d27a_07_mask.gif
#  extracting: data/train_masks/154ee2b6d27a_08_mask.gif
#  extracting: data/train_masks/154ee2b6d27a_09_mask.gif
#  extracting: data/train_masks/154ee2b6d27a_10_mask.gif
#   inflating: data/train_masks/154ee2b6d27a_11_mask.gif
#  extracting: data/train_masks/154ee2b6d27a_12_mask.gif
#  extracting: data/train_masks/154ee2b6d27a_13_mask.gif
#  extracting: data/train_masks/154ee2b6d27a_14_mask.gif
#  extracting: data/train_masks/154ee2b6d27a_15_mask.gif
#  extracting: data/train_masks/154ee2b6d27a_16_mask.gif
#  extracting: data/train_masks/169f5f6d8c9d_01_mask.gif
#  extracting: data/train_masks/169f5f6d8c9d_02_mask.gif
#  extracting: data/train_masks/169f5f6d8c9d_03_mask.gif
#  extracting: data/train_masks/169f5f6d8c9d_04_mask.gif
#  extracting: data/train_masks/169f5f6d8c9d_05_mask.gif
#  extracting: data/train_masks/169f5f6d8c9d_06_mask.gif
#  extracting: data/train_masks/169f5f6d8c9d_07_mask.gif
#  extracting: data/train_masks/169f5f6d8c9d_08_mask.gif
#  extracting: data/train_masks/169f5f6d8c9d_09_mask.gif
#  extracting: data/train_masks/169f5f6d8c9d_10_mask.gif
#  extracting: data/train_masks/169f5f6d8c9d_11_mask.gif
#  extracting: data/train_masks/169f5f6d8c9d_12_mask.gif
#  extracting: data/train_masks/169f5f6d8c9d_13_mask.gif
#  extracting: data/train_masks/169f5f6d8c9d_14_mask.gif
#  extracting: data/train_masks/169f5f6d8c9d_15_mask.gif
#  extracting: data/train_masks/169f5f6d8c9d_16_mask.gif
#  extracting: data/train_masks/16f0ec26d608_01_mask.gif
#  extracting: data/train_masks/16f0ec26d608_02_mask.gif
#  extracting: data/train_masks/16f0ec26d608_03_mask.gif
#  extracting: data/train_masks/16f0ec26d608_04_mask.gif
#  extracting: data/train_masks/16f0ec26d608_05_mask.gif
#  extracting: data/train_masks/16f0ec26d608_06_mask.gif
#  extracting: data/train_masks/16f0ec26d608_07_mask.gif
#  extracting: data/train_masks/16f0ec26d608_08_mask.gif
#  extracting: data/train_masks/16f0ec26d608_09_mask.gif
#  extracting: data/train_masks/16f0ec26d608_10_mask.gif
#  extracting: data/train_masks/16f0ec26d608_11_mask.gif
#  extracting: data/train_masks/16f0ec26d608_12_mask.gif
#  extracting: data/train_masks/16f0ec26d608_13_mask.gif
#  extracting: data/train_masks/16f0ec26d608_14_mask.gif
#  extracting: data/train_masks/16f0ec26d608_15_mask.gif
#  extracting: data/train_masks/16f0ec26d608_16_mask.gif
#  extracting: data/train_masks/189a2a32a615_01_mask.gif
#  extracting: data/train_masks/189a2a32a615_02_mask.gif
#  extracting: data/train_masks/189a2a32a615_03_mask.gif
#  extracting: data/train_masks/189a2a32a615_04_mask.gif
#  extracting: data/train_masks/189a2a32a615_05_mask.gif
#  extracting: data/train_masks/189a2a32a615_06_mask.gif
#  extracting: data/train_masks/189a2a32a615_07_mask.gif
#  extracting: data/train_masks/189a2a32a615_08_mask.gif
#  extracting: data/train_masks/189a2a32a615_09_mask.gif
#  extracting: data/train_masks/189a2a32a615_10_mask.gif
#  extracting: data/train_masks/189a2a32a615_11_mask.gif
#  extracting: data/train_masks/189a2a32a615_12_mask.gif
#  extracting: data/train_masks/189a2a32a615_13_mask.gif
#  extracting: data/train_masks/189a2a32a615_14_mask.gif
#  extracting: data/train_masks/189a2a32a615_15_mask.gif
#  extracting: data/train_masks/189a2a32a615_16_mask.gif
#  extracting: data/train_masks/1952e5f91de0_01_mask.gif
#  extracting: data/train_masks/1952e5f91de0_02_mask.gif
#  extracting: data/train_masks/1952e5f91de0_03_mask.gif
#  extracting: data/train_masks/1952e5f91de0_04_mask.gif
#  extracting: data/train_masks/1952e5f91de0_05_mask.gif
#  extracting: data/train_masks/1952e5f91de0_06_mask.gif
#  extracting: data/train_masks/1952e5f91de0_07_mask.gif
#  extracting: data/train_masks/1952e5f91de0_08_mask.gif
#  extracting: data/train_masks/1952e5f91de0_09_mask.gif
#  extracting: data/train_masks/1952e5f91de0_10_mask.gif
#  extracting: data/train_masks/1952e5f91de0_11_mask.gif
#  extracting: data/train_masks/1952e5f91de0_12_mask.gif
#  extracting: data/train_masks/1952e5f91de0_13_mask.gif
#  extracting: data/train_masks/1952e5f91de0_14_mask.gif
#  extracting: data/train_masks/1952e5f91de0_15_mask.gif
#  extracting: data/train_masks/1952e5f91de0_16_mask.gif
#  extracting: data/train_masks/1a17a1bd648b_01_mask.gif
#  extracting: data/train_masks/1a17a1bd648b_02_mask.gif
#  extracting: data/train_masks/1a17a1bd648b_03_mask.gif
#  extracting: data/train_masks/1a17a1bd648b_04_mask.gif
#  extracting: data/train_masks/1a17a1bd648b_05_mask.gif
#  extracting: data/train_masks/1a17a1bd648b_06_mask.gif
#  extracting: data/train_masks/1a17a1bd648b_07_mask.gif
#  extracting: data/train_masks/1a17a1bd648b_08_mask.gif
#  extracting: data/train_masks/1a17a1bd648b_09_mask.gif
#  extracting: data/train_masks/1a17a1bd648b_10_mask.gif
#  extracting: data/train_masks/1a17a1bd648b_11_mask.gif
#  extracting: data/train_masks/1a17a1bd648b_12_mask.gif
#  extracting: data/train_masks/1a17a1bd648b_13_mask.gif
#  extracting: data/train_masks/1a17a1bd648b_14_mask.gif
#  extracting: data/train_masks/1a17a1bd648b_15_mask.gif
#  extracting: data/train_masks/1a17a1bd648b_16_mask.gif
#  extracting: data/train_masks/1aba91a601c6_01_mask.gif
#  extracting: data/train_masks/1aba91a601c6_02_mask.gif
#  extracting: data/train_masks/1aba91a601c6_03_mask.gif
#  extracting: data/train_masks/1aba91a601c6_04_mask.gif
#   inflating: data/train_masks/1aba91a601c6_05_mask.gif
#  extracting: data/train_masks/1aba91a601c6_06_mask.gif
#   inflating: data/train_masks/1aba91a601c6_07_mask.gif
#  extracting: data/train_masks/1aba91a601c6_08_mask.gif
#  extracting: data/train_masks/1aba91a601c6_09_mask.gif
#   inflating: data/train_masks/1aba91a601c6_10_mask.gif
#  extracting: data/train_masks/1aba91a601c6_11_mask.gif
#  extracting: data/train_masks/1aba91a601c6_12_mask.gif
#   inflating: data/train_masks/1aba91a601c6_13_mask.gif
#   inflating: data/train_masks/1aba91a601c6_14_mask.gif
#  extracting: data/train_masks/1aba91a601c6_15_mask.gif
#  extracting: data/train_masks/1aba91a601c6_16_mask.gif
#  extracting: data/train_masks/1adaeb44f109_01_mask.gif
#  extracting: data/train_masks/1adaeb44f109_02_mask.gif
#  extracting: data/train_masks/1adaeb44f109_03_mask.gif
#  extracting: data/train_masks/1adaeb44f109_04_mask.gif
#  extracting: data/train_masks/1adaeb44f109_05_mask.gif
#  extracting: data/train_masks/1adaeb44f109_06_mask.gif
#  extracting: data/train_masks/1adaeb44f109_07_mask.gif
#  extracting: data/train_masks/1adaeb44f109_08_mask.gif
#  extracting: data/train_masks/1adaeb44f109_09_mask.gif
#  extracting: data/train_masks/1adaeb44f109_10_mask.gif
#   inflating: data/train_masks/1adaeb44f109_11_mask.gif
#  extracting: data/train_masks/1adaeb44f109_12_mask.gif
#  extracting: data/train_masks/1adaeb44f109_13_mask.gif
#   inflating: data/train_masks/1adaeb44f109_14_mask.gif
#  extracting: data/train_masks/1adaeb44f109_15_mask.gif
#  extracting: data/train_masks/1adaeb44f109_16_mask.gif
#  extracting: data/train_masks/1ae8a68a40e4_01_mask.gif
#  extracting: data/train_masks/1ae8a68a40e4_02_mask.gif
#  extracting: data/train_masks/1ae8a68a40e4_03_mask.gif
#  extracting: data/train_masks/1ae8a68a40e4_04_mask.gif
#  extracting: data/train_masks/1ae8a68a40e4_05_mask.gif
#   inflating: data/train_masks/1ae8a68a40e4_06_mask.gif
#  extracting: data/train_masks/1ae8a68a40e4_07_mask.gif
#  extracting: data/train_masks/1ae8a68a40e4_08_mask.gif
#  extracting: data/train_masks/1ae8a68a40e4_09_mask.gif
#  extracting: data/train_masks/1ae8a68a40e4_10_mask.gif
#  extracting: data/train_masks/1ae8a68a40e4_11_mask.gif
#   inflating: data/train_masks/1ae8a68a40e4_12_mask.gif
#  extracting: data/train_masks/1ae8a68a40e4_13_mask.gif
#  extracting: data/train_masks/1ae8a68a40e4_14_mask.gif
#  extracting: data/train_masks/1ae8a68a40e4_15_mask.gif
#  extracting: data/train_masks/1ae8a68a40e4_16_mask.gif
#  extracting: data/train_masks/1b25ea8ba94d_01_mask.gif
#  extracting: data/train_masks/1b25ea8ba94d_02_mask.gif
#  extracting: data/train_masks/1b25ea8ba94d_03_mask.gif
#  extracting: data/train_masks/1b25ea8ba94d_04_mask.gif
#  extracting: data/train_masks/1b25ea8ba94d_05_mask.gif
#  extracting: data/train_masks/1b25ea8ba94d_06_mask.gif
#  extracting: data/train_masks/1b25ea8ba94d_07_mask.gif
#  extracting: data/train_masks/1b25ea8ba94d_08_mask.gif
#  extracting: data/train_masks/1b25ea8ba94d_09_mask.gif
#  extracting: data/train_masks/1b25ea8ba94d_10_mask.gif
#  extracting: data/train_masks/1b25ea8ba94d_11_mask.gif
#  extracting: data/train_masks/1b25ea8ba94d_12_mask.gif
#  extracting: data/train_masks/1b25ea8ba94d_13_mask.gif
#  extracting: data/train_masks/1b25ea8ba94d_14_mask.gif
#  extracting: data/train_masks/1b25ea8ba94d_15_mask.gif
#  extracting: data/train_masks/1b25ea8ba94d_16_mask.gif
#  extracting: data/train_masks/1ba84b81628e_01_mask.gif
#  extracting: data/train_masks/1ba84b81628e_02_mask.gif
#  extracting: data/train_masks/1ba84b81628e_03_mask.gif
#  extracting: data/train_masks/1ba84b81628e_04_mask.gif
#  extracting: data/train_masks/1ba84b81628e_05_mask.gif
#  extracting: data/train_masks/1ba84b81628e_06_mask.gif
#  extracting: data/train_masks/1ba84b81628e_07_mask.gif
#  extracting: data/train_masks/1ba84b81628e_08_mask.gif
#  extracting: data/train_masks/1ba84b81628e_09_mask.gif
#  extracting: data/train_masks/1ba84b81628e_10_mask.gif
#  extracting: data/train_masks/1ba84b81628e_11_mask.gif
#  extracting: data/train_masks/1ba84b81628e_12_mask.gif
#  extracting: data/train_masks/1ba84b81628e_13_mask.gif
#  extracting: data/train_masks/1ba84b81628e_14_mask.gif
#  extracting: data/train_masks/1ba84b81628e_15_mask.gif
#  extracting: data/train_masks/1ba84b81628e_16_mask.gif
#  extracting: data/train_masks/1c5748340af8_01_mask.gif
#  extracting: data/train_masks/1c5748340af8_02_mask.gif
#  extracting: data/train_masks/1c5748340af8_03_mask.gif
#  extracting: data/train_masks/1c5748340af8_04_mask.gif
#  extracting: data/train_masks/1c5748340af8_05_mask.gif
#  extracting: data/train_masks/1c5748340af8_06_mask.gif
#  extracting: data/train_masks/1c5748340af8_07_mask.gif
#  extracting: data/train_masks/1c5748340af8_08_mask.gif
#  extracting: data/train_masks/1c5748340af8_09_mask.gif
#  extracting: data/train_masks/1c5748340af8_10_mask.gif
#  extracting: data/train_masks/1c5748340af8_11_mask.gif
#  extracting: data/train_masks/1c5748340af8_12_mask.gif
#  extracting: data/train_masks/1c5748340af8_13_mask.gif
#  extracting: data/train_masks/1c5748340af8_14_mask.gif
#  extracting: data/train_masks/1c5748340af8_15_mask.gif
#  extracting: data/train_masks/1c5748340af8_16_mask.gif
#   inflating: data/train_masks/1e6f48393e17_01_mask.gif
#  extracting: data/train_masks/1e6f48393e17_02_mask.gif
#  extracting: data/train_masks/1e6f48393e17_03_mask.gif
#  extracting: data/train_masks/1e6f48393e17_04_mask.gif
#  extracting: data/train_masks/1e6f48393e17_05_mask.gif
#  extracting: data/train_masks/1e6f48393e17_06_mask.gif
#  extracting: data/train_masks/1e6f48393e17_07_mask.gif
#  extracting: data/train_masks/1e6f48393e17_08_mask.gif
#  extracting: data/train_masks/1e6f48393e17_09_mask.gif
#  extracting: data/train_masks/1e6f48393e17_10_mask.gif
#   inflating: data/train_masks/1e6f48393e17_11_mask.gif
#  extracting: data/train_masks/1e6f48393e17_12_mask.gif
#   inflating: data/train_masks/1e6f48393e17_13_mask.gif
#  extracting: data/train_masks/1e6f48393e17_14_mask.gif
#  extracting: data/train_masks/1e6f48393e17_15_mask.gif
#  extracting: data/train_masks/1e6f48393e17_16_mask.gif
#  extracting: data/train_masks/1e89e1af42e7_01_mask.gif
#  extracting: data/train_masks/1e89e1af42e7_02_mask.gif
#  extracting: data/train_masks/1e89e1af42e7_03_mask.gif
#   inflating: data/train_masks/1e89e1af42e7_04_mask.gif
#   inflating: data/train_masks/1e89e1af42e7_05_mask.gif
#  extracting: data/train_masks/1e89e1af42e7_06_mask.gif
#   inflating: data/train_masks/1e89e1af42e7_07_mask.gif
#  extracting: data/train_masks/1e89e1af42e7_08_mask.gif
#   inflating: data/train_masks/1e89e1af42e7_09_mask.gif
#  extracting: data/train_masks/1e89e1af42e7_10_mask.gif
#  extracting: data/train_masks/1e89e1af42e7_11_mask.gif
#  extracting: data/train_masks/1e89e1af42e7_12_mask.gif
#   inflating: data/train_masks/1e89e1af42e7_13_mask.gif
#  extracting: data/train_masks/1e89e1af42e7_14_mask.gif
#  extracting: data/train_masks/1e89e1af42e7_15_mask.gif
#  extracting: data/train_masks/1e89e1af42e7_16_mask.gif
#  extracting: data/train_masks/21a7e6726ee3_01_mask.gif
#  extracting: data/train_masks/21a7e6726ee3_02_mask.gif
#  extracting: data/train_masks/21a7e6726ee3_03_mask.gif
#  extracting: data/train_masks/21a7e6726ee3_04_mask.gif
#  extracting: data/train_masks/21a7e6726ee3_05_mask.gif
#  extracting: data/train_masks/21a7e6726ee3_06_mask.gif
#  extracting: data/train_masks/21a7e6726ee3_07_mask.gif
#  extracting: data/train_masks/21a7e6726ee3_08_mask.gif
#  extracting: data/train_masks/21a7e6726ee3_09_mask.gif
#  extracting: data/train_masks/21a7e6726ee3_10_mask.gif
#  extracting: data/train_masks/21a7e6726ee3_11_mask.gif
#  extracting: data/train_masks/21a7e6726ee3_12_mask.gif
#  extracting: data/train_masks/21a7e6726ee3_13_mask.gif
#  extracting: data/train_masks/21a7e6726ee3_14_mask.gif
#  extracting: data/train_masks/21a7e6726ee3_15_mask.gif
#  extracting: data/train_masks/21a7e6726ee3_16_mask.gif
#  extracting: data/train_masks/2267f4aa0d2c_01_mask.gif
#  extracting: data/train_masks/2267f4aa0d2c_02_mask.gif
#   inflating: data/train_masks/2267f4aa0d2c_03_mask.gif
#  extracting: data/train_masks/2267f4aa0d2c_04_mask.gif
#  extracting: data/train_masks/2267f4aa0d2c_05_mask.gif
#  extracting: data/train_masks/2267f4aa0d2c_06_mask.gif
#   inflating: data/train_masks/2267f4aa0d2c_07_mask.gif
#  extracting: data/train_masks/2267f4aa0d2c_08_mask.gif
#   inflating: data/train_masks/2267f4aa0d2c_09_mask.gif
#  extracting: data/train_masks/2267f4aa0d2c_10_mask.gif
#   inflating: data/train_masks/2267f4aa0d2c_11_mask.gif
#  extracting: data/train_masks/2267f4aa0d2c_12_mask.gif
#  extracting: data/train_masks/2267f4aa0d2c_13_mask.gif
#   inflating: data/train_masks/2267f4aa0d2c_14_mask.gif
#   inflating: data/train_masks/2267f4aa0d2c_15_mask.gif
#  extracting: data/train_masks/2267f4aa0d2c_16_mask.gif
#  extracting: data/train_masks/2335eef27de6_01_mask.gif
#   inflating: data/train_masks/2335eef27de6_02_mask.gif
#  extracting: data/train_masks/2335eef27de6_03_mask.gif
#  extracting: data/train_masks/2335eef27de6_04_mask.gif
#  extracting: data/train_masks/2335eef27de6_05_mask.gif
#  extracting: data/train_masks/2335eef27de6_06_mask.gif
#   inflating: data/train_masks/2335eef27de6_07_mask.gif
#  extracting: data/train_masks/2335eef27de6_08_mask.gif
#  extracting: data/train_masks/2335eef27de6_09_mask.gif
#  extracting: data/train_masks/2335eef27de6_10_mask.gif
#   inflating: data/train_masks/2335eef27de6_11_mask.gif
#  extracting: data/train_masks/2335eef27de6_12_mask.gif
#   inflating: data/train_masks/2335eef27de6_13_mask.gif
#  extracting: data/train_masks/2335eef27de6_14_mask.gif
#  extracting: data/train_masks/2335eef27de6_15_mask.gif
#   inflating: data/train_masks/2335eef27de6_16_mask.gif
#  extracting: data/train_masks/23c088f6ec27_01_mask.gif
#   inflating: data/train_masks/23c088f6ec27_02_mask.gif
#   inflating: data/train_masks/23c088f6ec27_03_mask.gif
#   inflating: data/train_masks/23c088f6ec27_04_mask.gif
#   inflating: data/train_masks/23c088f6ec27_05_mask.gif
#   inflating: data/train_masks/23c088f6ec27_06_mask.gif
#   inflating: data/train_masks/23c088f6ec27_07_mask.gif
#   inflating: data/train_masks/23c088f6ec27_08_mask.gif
#   inflating: data/train_masks/23c088f6ec27_09_mask.gif
#   inflating: data/train_masks/23c088f6ec27_10_mask.gif
#  extracting: data/train_masks/23c088f6ec27_11_mask.gif
#  extracting: data/train_masks/23c088f6ec27_12_mask.gif
#   inflating: data/train_masks/23c088f6ec27_13_mask.gif
#  extracting: data/train_masks/23c088f6ec27_14_mask.gif
#  extracting: data/train_masks/23c088f6ec27_15_mask.gif
#  extracting: data/train_masks/23c088f6ec27_16_mask.gif
#  extracting: data/train_masks/245f9c9eab8a_01_mask.gif
#  extracting: data/train_masks/245f9c9eab8a_02_mask.gif
#  extracting: data/train_masks/245f9c9eab8a_03_mask.gif
#  extracting: data/train_masks/245f9c9eab8a_04_mask.gif
#  extracting: data/train_masks/245f9c9eab8a_05_mask.gif
#  extracting: data/train_masks/245f9c9eab8a_06_mask.gif
#  extracting: data/train_masks/245f9c9eab8a_07_mask.gif
#  extracting: data/train_masks/245f9c9eab8a_08_mask.gif
#  extracting: data/train_masks/245f9c9eab8a_09_mask.gif
#  extracting: data/train_masks/245f9c9eab8a_10_mask.gif
#  extracting: data/train_masks/245f9c9eab8a_11_mask.gif
#  extracting: data/train_masks/245f9c9eab8a_12_mask.gif
#  extracting: data/train_masks/245f9c9eab8a_13_mask.gif
#  extracting: data/train_masks/245f9c9eab8a_14_mask.gif
#  extracting: data/train_masks/245f9c9eab8a_15_mask.gif
#  extracting: data/train_masks/245f9c9eab8a_16_mask.gif
#  extracting: data/train_masks/26ccab021981_01_mask.gif
#  extracting: data/train_masks/26ccab021981_02_mask.gif
#  extracting: data/train_masks/26ccab021981_03_mask.gif
#  extracting: data/train_masks/26ccab021981_04_mask.gif
#  extracting: data/train_masks/26ccab021981_05_mask.gif
#  extracting: data/train_masks/26ccab021981_06_mask.gif
#  extracting: data/train_masks/26ccab021981_07_mask.gif
#  extracting: data/train_masks/26ccab021981_08_mask.gif
#  extracting: data/train_masks/26ccab021981_09_mask.gif
#  extracting: data/train_masks/26ccab021981_10_mask.gif
#  extracting: data/train_masks/26ccab021981_11_mask.gif
#  extracting: data/train_masks/26ccab021981_12_mask.gif
#  extracting: data/train_masks/26ccab021981_13_mask.gif
#  extracting: data/train_masks/26ccab021981_14_mask.gif
#  extracting: data/train_masks/26ccab021981_15_mask.gif
#  extracting: data/train_masks/26ccab021981_16_mask.gif
#   inflating: data/train_masks/28109f18d9d4_01_mask.gif
#  extracting: data/train_masks/28109f18d9d4_02_mask.gif
#  extracting: data/train_masks/28109f18d9d4_03_mask.gif
#  extracting: data/train_masks/28109f18d9d4_04_mask.gif
#   inflating: data/train_masks/28109f18d9d4_05_mask.gif
#   inflating: data/train_masks/28109f18d9d4_06_mask.gif
#   inflating: data/train_masks/28109f18d9d4_07_mask.gif
#  extracting: data/train_masks/28109f18d9d4_08_mask.gif
#  extracting: data/train_masks/28109f18d9d4_09_mask.gif
#  extracting: data/train_masks/28109f18d9d4_10_mask.gif
#  extracting: data/train_masks/28109f18d9d4_11_mask.gif
#   inflating: data/train_masks/28109f18d9d4_12_mask.gif
#   inflating: data/train_masks/28109f18d9d4_13_mask.gif
#   inflating: data/train_masks/28109f18d9d4_14_mask.gif
#   inflating: data/train_masks/28109f18d9d4_15_mask.gif
#  extracting: data/train_masks/28109f18d9d4_16_mask.gif
#  extracting: data/train_masks/28d7fb5ba432_01_mask.gif
#  extracting: data/train_masks/28d7fb5ba432_02_mask.gif
#  extracting: data/train_masks/28d7fb5ba432_03_mask.gif
#  extracting: data/train_masks/28d7fb5ba432_04_mask.gif
#  extracting: data/train_masks/28d7fb5ba432_05_mask.gif
#  extracting: data/train_masks/28d7fb5ba432_06_mask.gif
#  extracting: data/train_masks/28d7fb5ba432_07_mask.gif
#  extracting: data/train_masks/28d7fb5ba432_08_mask.gif
#  extracting: data/train_masks/28d7fb5ba432_09_mask.gif
#   inflating: data/train_masks/28d7fb5ba432_10_mask.gif
#  extracting: data/train_masks/28d7fb5ba432_11_mask.gif
#  extracting: data/train_masks/28d7fb5ba432_12_mask.gif
#  extracting: data/train_masks/28d7fb5ba432_13_mask.gif
#  extracting: data/train_masks/28d7fb5ba432_14_mask.gif
#  extracting: data/train_masks/28d7fb5ba432_15_mask.gif
#  extracting: data/train_masks/28d7fb5ba432_16_mask.gif
#  extracting: data/train_masks/28d9a149cb02_01_mask.gif
#  extracting: data/train_masks/28d9a149cb02_02_mask.gif
#  extracting: data/train_masks/28d9a149cb02_03_mask.gif
#  extracting: data/train_masks/28d9a149cb02_04_mask.gif
#  extracting: data/train_masks/28d9a149cb02_05_mask.gif
#  extracting: data/train_masks/28d9a149cb02_06_mask.gif
#  extracting: data/train_masks/28d9a149cb02_07_mask.gif
#  extracting: data/train_masks/28d9a149cb02_08_mask.gif
#  extracting: data/train_masks/28d9a149cb02_09_mask.gif
#  extracting: data/train_masks/28d9a149cb02_10_mask.gif
#  extracting: data/train_masks/28d9a149cb02_11_mask.gif
#  extracting: data/train_masks/28d9a149cb02_12_mask.gif
#  extracting: data/train_masks/28d9a149cb02_13_mask.gif
#  extracting: data/train_masks/28d9a149cb02_14_mask.gif
#  extracting: data/train_masks/28d9a149cb02_15_mask.gif
#  extracting: data/train_masks/28d9a149cb02_16_mask.gif
#  extracting: data/train_masks/292f59c6a347_01_mask.gif
#  extracting: data/train_masks/292f59c6a347_02_mask.gif
#  extracting: data/train_masks/292f59c6a347_03_mask.gif
#  extracting: data/train_masks/292f59c6a347_04_mask.gif
#  extracting: data/train_masks/292f59c6a347_05_mask.gif
#  extracting: data/train_masks/292f59c6a347_06_mask.gif
#  extracting: data/train_masks/292f59c6a347_07_mask.gif
#  extracting: data/train_masks/292f59c6a347_08_mask.gif
#  extracting: data/train_masks/292f59c6a347_09_mask.gif
#  extracting: data/train_masks/292f59c6a347_10_mask.gif
#  extracting: data/train_masks/292f59c6a347_11_mask.gif
#  extracting: data/train_masks/292f59c6a347_12_mask.gif
#  extracting: data/train_masks/292f59c6a347_13_mask.gif
#  extracting: data/train_masks/292f59c6a347_14_mask.gif
#  extracting: data/train_masks/292f59c6a347_15_mask.gif
#  extracting: data/train_masks/292f59c6a347_16_mask.gif
#  extracting: data/train_masks/293a0fa72e5b_01_mask.gif
#  extracting: data/train_masks/293a0fa72e5b_02_mask.gif
#  extracting: data/train_masks/293a0fa72e5b_03_mask.gif
#  extracting: data/train_masks/293a0fa72e5b_04_mask.gif
#   inflating: data/train_masks/293a0fa72e5b_05_mask.gif
#  extracting: data/train_masks/293a0fa72e5b_06_mask.gif
#   inflating: data/train_masks/293a0fa72e5b_07_mask.gif
#  extracting: data/train_masks/293a0fa72e5b_08_mask.gif
#  extracting: data/train_masks/293a0fa72e5b_09_mask.gif
#  extracting: data/train_masks/293a0fa72e5b_10_mask.gif
#  extracting: data/train_masks/293a0fa72e5b_11_mask.gif
#   inflating: data/train_masks/293a0fa72e5b_12_mask.gif
#  extracting: data/train_masks/293a0fa72e5b_13_mask.gif
#  extracting: data/train_masks/293a0fa72e5b_14_mask.gif
#   inflating: data/train_masks/293a0fa72e5b_15_mask.gif
#  extracting: data/train_masks/293a0fa72e5b_16_mask.gif
#  extracting: data/train_masks/2990f858e939_01_mask.gif
#  extracting: data/train_masks/2990f858e939_02_mask.gif
#  extracting: data/train_masks/2990f858e939_03_mask.gif
#  extracting: data/train_masks/2990f858e939_04_mask.gif
#   inflating: data/train_masks/2990f858e939_05_mask.gif
#  extracting: data/train_masks/2990f858e939_06_mask.gif
#   inflating: data/train_masks/2990f858e939_07_mask.gif
#  extracting: data/train_masks/2990f858e939_08_mask.gif
#  extracting: data/train_masks/2990f858e939_09_mask.gif
#  extracting: data/train_masks/2990f858e939_10_mask.gif
#  extracting: data/train_masks/2990f858e939_11_mask.gif
#   inflating: data/train_masks/2990f858e939_12_mask.gif
#  extracting: data/train_masks/2990f858e939_13_mask.gif
#  extracting: data/train_masks/2990f858e939_14_mask.gif
#  extracting: data/train_masks/2990f858e939_15_mask.gif
#  extracting: data/train_masks/2990f858e939_16_mask.gif
#  extracting: data/train_masks/2a4a8964ebf3_01_mask.gif
#  extracting: data/train_masks/2a4a8964ebf3_02_mask.gif
#  extracting: data/train_masks/2a4a8964ebf3_03_mask.gif
#  extracting: data/train_masks/2a4a8964ebf3_04_mask.gif
#  extracting: data/train_masks/2a4a8964ebf3_05_mask.gif
#  extracting: data/train_masks/2a4a8964ebf3_06_mask.gif
#  extracting: data/train_masks/2a4a8964ebf3_07_mask.gif
#  extracting: data/train_masks/2a4a8964ebf3_08_mask.gif
#  extracting: data/train_masks/2a4a8964ebf3_09_mask.gif
#  extracting: data/train_masks/2a4a8964ebf3_10_mask.gif
#  extracting: data/train_masks/2a4a8964ebf3_11_mask.gif
#  extracting: data/train_masks/2a4a8964ebf3_12_mask.gif
#  extracting: data/train_masks/2a4a8964ebf3_13_mask.gif
#  extracting: data/train_masks/2a4a8964ebf3_14_mask.gif
#  extracting: data/train_masks/2a4a8964ebf3_15_mask.gif
#  extracting: data/train_masks/2a4a8964ebf3_16_mask.gif
#  extracting: data/train_masks/2af7c265531e_01_mask.gif
#  extracting: data/train_masks/2af7c265531e_02_mask.gif
#  extracting: data/train_masks/2af7c265531e_03_mask.gif
#  extracting: data/train_masks/2af7c265531e_04_mask.gif
#  extracting: data/train_masks/2af7c265531e_05_mask.gif
#  extracting: data/train_masks/2af7c265531e_06_mask.gif
#  extracting: data/train_masks/2af7c265531e_07_mask.gif
#  extracting: data/train_masks/2af7c265531e_08_mask.gif
#  extracting: data/train_masks/2af7c265531e_09_mask.gif
#  extracting: data/train_masks/2af7c265531e_10_mask.gif
#  extracting: data/train_masks/2af7c265531e_11_mask.gif
#  extracting: data/train_masks/2af7c265531e_12_mask.gif
#  extracting: data/train_masks/2af7c265531e_13_mask.gif
#  extracting: data/train_masks/2af7c265531e_14_mask.gif
#  extracting: data/train_masks/2af7c265531e_15_mask.gif
#  extracting: data/train_masks/2af7c265531e_16_mask.gif
#  extracting: data/train_masks/2c57132da7a0_01_mask.gif
#  extracting: data/train_masks/2c57132da7a0_02_mask.gif
#  extracting: data/train_masks/2c57132da7a0_03_mask.gif
#  extracting: data/train_masks/2c57132da7a0_04_mask.gif
#  extracting: data/train_masks/2c57132da7a0_05_mask.gif
#  extracting: data/train_masks/2c57132da7a0_06_mask.gif
#  extracting: data/train_masks/2c57132da7a0_07_mask.gif
#  extracting: data/train_masks/2c57132da7a0_08_mask.gif
#  extracting: data/train_masks/2c57132da7a0_09_mask.gif
#  extracting: data/train_masks/2c57132da7a0_10_mask.gif
#  extracting: data/train_masks/2c57132da7a0_11_mask.gif
#  extracting: data/train_masks/2c57132da7a0_12_mask.gif
#  extracting: data/train_masks/2c57132da7a0_13_mask.gif
#  extracting: data/train_masks/2c57132da7a0_14_mask.gif
#  extracting: data/train_masks/2c57132da7a0_15_mask.gif
#  extracting: data/train_masks/2c57132da7a0_16_mask.gif
#  extracting: data/train_masks/2cb06c1f5bb1_01_mask.gif
#  extracting: data/train_masks/2cb06c1f5bb1_02_mask.gif
#  extracting: data/train_masks/2cb06c1f5bb1_03_mask.gif
#  extracting: data/train_masks/2cb06c1f5bb1_04_mask.gif
#  extracting: data/train_masks/2cb06c1f5bb1_05_mask.gif
#  extracting: data/train_masks/2cb06c1f5bb1_06_mask.gif
#  extracting: data/train_masks/2cb06c1f5bb1_07_mask.gif
#  extracting: data/train_masks/2cb06c1f5bb1_08_mask.gif
#  extracting: data/train_masks/2cb06c1f5bb1_09_mask.gif
#  extracting: data/train_masks/2cb06c1f5bb1_10_mask.gif
#  extracting: data/train_masks/2cb06c1f5bb1_11_mask.gif
#  extracting: data/train_masks/2cb06c1f5bb1_12_mask.gif
#  extracting: data/train_masks/2cb06c1f5bb1_13_mask.gif
#  extracting: data/train_masks/2cb06c1f5bb1_14_mask.gif
#  extracting: data/train_masks/2cb06c1f5bb1_15_mask.gif
#  extracting: data/train_masks/2cb06c1f5bb1_16_mask.gif
#  extracting: data/train_masks/2cb91c2543fa_01_mask.gif
#  extracting: data/train_masks/2cb91c2543fa_02_mask.gif
#   inflating: data/train_masks/2cb91c2543fa_03_mask.gif
#   inflating: data/train_masks/2cb91c2543fa_04_mask.gif
#   inflating: data/train_masks/2cb91c2543fa_05_mask.gif
#   inflating: data/train_masks/2cb91c2543fa_06_mask.gif
#   inflating: data/train_masks/2cb91c2543fa_07_mask.gif
#  extracting: data/train_masks/2cb91c2543fa_08_mask.gif
#   inflating: data/train_masks/2cb91c2543fa_09_mask.gif
#  extracting: data/train_masks/2cb91c2543fa_10_mask.gif
#  extracting: data/train_masks/2cb91c2543fa_11_mask.gif
#   inflating: data/train_masks/2cb91c2543fa_12_mask.gif
#   inflating: data/train_masks/2cb91c2543fa_13_mask.gif
#  extracting: data/train_masks/2cb91c2543fa_14_mask.gif
#  extracting: data/train_masks/2cb91c2543fa_15_mask.gif
#  extracting: data/train_masks/2cb91c2543fa_16_mask.gif
#  extracting: data/train_masks/2ea62c1beee7_01_mask.gif
#   inflating: data/train_masks/2ea62c1beee7_02_mask.gif
#  extracting: data/train_masks/2ea62c1beee7_03_mask.gif
#  extracting: data/train_masks/2ea62c1beee7_04_mask.gif
#   inflating: data/train_masks/2ea62c1beee7_05_mask.gif
#   inflating: data/train_masks/2ea62c1beee7_06_mask.gif
#  extracting: data/train_masks/2ea62c1beee7_07_mask.gif
#   inflating: data/train_masks/2ea62c1beee7_08_mask.gif
#  extracting: data/train_masks/2ea62c1beee7_09_mask.gif
#   inflating: data/train_masks/2ea62c1beee7_10_mask.gif
#  extracting: data/train_masks/2ea62c1beee7_11_mask.gif
#   inflating: data/train_masks/2ea62c1beee7_12_mask.gif
#   inflating: data/train_masks/2ea62c1beee7_13_mask.gif
#   inflating: data/train_masks/2ea62c1beee7_14_mask.gif
#  extracting: data/train_masks/2ea62c1beee7_15_mask.gif
#   inflating: data/train_masks/2ea62c1beee7_16_mask.gif
#  extracting: data/train_masks/2f39abb12388_01_mask.gif
# ...
#  extracting: data/train_masks/f4cd1286d5f4_09_mask.gif
#  extracting: data/train_masks/f4cd1286d5f4_10_mask.gif
#  extracting: data/train_masks/f4cd1286d5f4_11_mask.gif
#  extracting: data/train_masks/f4cd1286d5f4_12_mask.gif
#   inflating: data/train_masks/f4cd1286d5f4_13_mask.gif
#  extracting: data/train_masks/f4cd1286d5f4_14_mask.gif
#  extracting: data/train_masks/f4cd1286d5f4_15_mask.gif
#  extracting: data/train_masks/f4cd1286d5f4_16_mask.gif
#  extracting: data/train_masks/f591b4f2e006_01_mask.gif
#  extracting: data/train_masks/f591b4f2e006_02_mask.gif
#  extracting: data/train_masks/f591b4f2e006_03_mask.gif
#  extracting: data/train_masks/f591b4f2e006_04_mask.gif
#  extracting: data/train_masks/f591b4f2e006_05_mask.gif
#  extracting: data/train_masks/f591b4f2e006_06_mask.gif
#   inflating: data/train_masks/f591b4f2e006_07_mask.gif
#  extracting: data/train_masks/f591b4f2e006_08_mask.gif
#  extracting: data/train_masks/f591b4f2e006_09_mask.gif
#  extracting: data/train_masks/f591b4f2e006_10_mask.gif
#   inflating: data/train_masks/f591b4f2e006_11_mask.gif
#  extracting: data/train_masks/f591b4f2e006_12_mask.gif
#   inflating: data/train_masks/f591b4f2e006_13_mask.gif
#  extracting: data/train_masks/f591b4f2e006_14_mask.gif
#  extracting: data/train_masks/f591b4f2e006_15_mask.gif
#  extracting: data/train_masks/f591b4f2e006_16_mask.gif
#  extracting: data/train_masks/f70052627830_01_mask.gif
#  extracting: data/train_masks/f70052627830_02_mask.gif
#  extracting: data/train_masks/f70052627830_03_mask.gif
#  extracting: data/train_masks/f70052627830_04_mask.gif
#   inflating: data/train_masks/f70052627830_05_mask.gif
#  extracting: data/train_masks/f70052627830_06_mask.gif
#  extracting: data/train_masks/f70052627830_07_mask.gif
#  extracting: data/train_masks/f70052627830_08_mask.gif
#  extracting: data/train_masks/f70052627830_09_mask.gif
#  extracting: data/train_masks/f70052627830_10_mask.gif
#  extracting: data/train_masks/f70052627830_11_mask.gif
#   inflating: data/train_masks/f70052627830_12_mask.gif
#   inflating: data/train_masks/f70052627830_13_mask.gif
#  extracting: data/train_masks/f70052627830_14_mask.gif
#  extracting: data/train_masks/f70052627830_15_mask.gif
#  extracting: data/train_masks/f70052627830_16_mask.gif
#  extracting: data/train_masks/f707d6fbc0cd_01_mask.gif
#  extracting: data/train_masks/f707d6fbc0cd_02_mask.gif
#  extracting: data/train_masks/f707d6fbc0cd_03_mask.gif
#  extracting: data/train_masks/f707d6fbc0cd_04_mask.gif
#  extracting: data/train_masks/f707d6fbc0cd_05_mask.gif
#  extracting: data/train_masks/f707d6fbc0cd_06_mask.gif
#  extracting: data/train_masks/f707d6fbc0cd_07_mask.gif
#  extracting: data/train_masks/f707d6fbc0cd_08_mask.gif
#  extracting: data/train_masks/f707d6fbc0cd_09_mask.gif
#  extracting: data/train_masks/f707d6fbc0cd_10_mask.gif
#  extracting: data/train_masks/f707d6fbc0cd_11_mask.gif
#  extracting: data/train_masks/f707d6fbc0cd_12_mask.gif
#  extracting: data/train_masks/f707d6fbc0cd_13_mask.gif
#  extracting: data/train_masks/f707d6fbc0cd_14_mask.gif
#  extracting: data/train_masks/f707d6fbc0cd_15_mask.gif
#  extracting: data/train_masks/f707d6fbc0cd_16_mask.gif
#  extracting: data/train_masks/f7ad86e13ed7_01_mask.gif
#  extracting: data/train_masks/f7ad86e13ed7_02_mask.gif
#   inflating: data/train_masks/f7ad86e13ed7_03_mask.gif
#  extracting: data/train_masks/f7ad86e13ed7_04_mask.gif
#   inflating: data/train_masks/f7ad86e13ed7_05_mask.gif
#  extracting: data/train_masks/f7ad86e13ed7_06_mask.gif
#  extracting: data/train_masks/f7ad86e13ed7_07_mask.gif
#  extracting: data/train_masks/f7ad86e13ed7_08_mask.gif
#  extracting: data/train_masks/f7ad86e13ed7_09_mask.gif
#  extracting: data/train_masks/f7ad86e13ed7_10_mask.gif
#  extracting: data/train_masks/f7ad86e13ed7_11_mask.gif
#  extracting: data/train_masks/f7ad86e13ed7_12_mask.gif
#  extracting: data/train_masks/f7ad86e13ed7_13_mask.gif
#  extracting: data/train_masks/f7ad86e13ed7_14_mask.gif
#  extracting: data/train_masks/f7ad86e13ed7_15_mask.gif
#  extracting: data/train_masks/f7ad86e13ed7_16_mask.gif
#   inflating: data/train_masks/f8b6f4c39204_01_mask.gif
#  extracting: data/train_masks/f8b6f4c39204_02_mask.gif
#  extracting: data/train_masks/f8b6f4c39204_03_mask.gif
#  extracting: data/train_masks/f8b6f4c39204_04_mask.gif
#   inflating: data/train_masks/f8b6f4c39204_05_mask.gif
#  extracting: data/train_masks/f8b6f4c39204_06_mask.gif
#   inflating: data/train_masks/f8b6f4c39204_07_mask.gif
#  extracting: data/train_masks/f8b6f4c39204_08_mask.gif
#  extracting: data/train_masks/f8b6f4c39204_09_mask.gif
#  extracting: data/train_masks/f8b6f4c39204_10_mask.gif
#  extracting: data/train_masks/f8b6f4c39204_11_mask.gif
#   inflating: data/train_masks/f8b6f4c39204_12_mask.gif
#  extracting: data/train_masks/f8b6f4c39204_13_mask.gif
#  extracting: data/train_masks/f8b6f4c39204_14_mask.gif
#  extracting: data/train_masks/f8b6f4c39204_15_mask.gif
#  extracting: data/train_masks/f8b6f4c39204_16_mask.gif
#  extracting: data/train_masks/f98dbe8a5ee2_01_mask.gif
#  extracting: data/train_masks/f98dbe8a5ee2_02_mask.gif
#  extracting: data/train_masks/f98dbe8a5ee2_03_mask.gif
#  extracting: data/train_masks/f98dbe8a5ee2_04_mask.gif
#  extracting: data/train_masks/f98dbe8a5ee2_05_mask.gif
#  extracting: data/train_masks/f98dbe8a5ee2_06_mask.gif
#  extracting: data/train_masks/f98dbe8a5ee2_07_mask.gif
#   inflating: data/train_masks/f98dbe8a5ee2_08_mask.gif
#  extracting: data/train_masks/f98dbe8a5ee2_09_mask.gif
#   inflating: data/train_masks/f98dbe8a5ee2_10_mask.gif
#  extracting: data/train_masks/f98dbe8a5ee2_11_mask.gif
#   inflating: data/train_masks/f98dbe8a5ee2_12_mask.gif
#  extracting: data/train_masks/f98dbe8a5ee2_13_mask.gif
#  extracting: data/train_masks/f98dbe8a5ee2_14_mask.gif
#  extracting: data/train_masks/f98dbe8a5ee2_15_mask.gif
#  extracting: data/train_masks/f98dbe8a5ee2_16_mask.gif
#  extracting: data/train_masks/fa006be8b6d9_01_mask.gif
#  extracting: data/train_masks/fa006be8b6d9_02_mask.gif
#  extracting: data/train_masks/fa006be8b6d9_03_mask.gif
#  extracting: data/train_masks/fa006be8b6d9_04_mask.gif
#   inflating: data/train_masks/fa006be8b6d9_05_mask.gif
#  extracting: data/train_masks/fa006be8b6d9_06_mask.gif
#  extracting: data/train_masks/fa006be8b6d9_07_mask.gif
#  extracting: data/train_masks/fa006be8b6d9_08_mask.gif
#  extracting: data/train_masks/fa006be8b6d9_09_mask.gif
#  extracting: data/train_masks/fa006be8b6d9_10_mask.gif
#  extracting: data/train_masks/fa006be8b6d9_11_mask.gif
#   inflating: data/train_masks/fa006be8b6d9_12_mask.gif
#   inflating: data/train_masks/fa006be8b6d9_13_mask.gif
#  extracting: data/train_masks/fa006be8b6d9_14_mask.gif
#  extracting: data/train_masks/fa006be8b6d9_15_mask.gif
#  extracting: data/train_masks/fa006be8b6d9_16_mask.gif
#  extracting: data/train_masks/fa613ac8eac5_01_mask.gif
#  extracting: data/train_masks/fa613ac8eac5_02_mask.gif
#  extracting: data/train_masks/fa613ac8eac5_03_mask.gif
#  extracting: data/train_masks/fa613ac8eac5_04_mask.gif
#  extracting: data/train_masks/fa613ac8eac5_05_mask.gif
#  extracting: data/train_masks/fa613ac8eac5_06_mask.gif
#  extracting: data/train_masks/fa613ac8eac5_07_mask.gif
#  extracting: data/train_masks/fa613ac8eac5_08_mask.gif
#  extracting: data/train_masks/fa613ac8eac5_09_mask.gif
#  extracting: data/train_masks/fa613ac8eac5_10_mask.gif
#  extracting: data/train_masks/fa613ac8eac5_11_mask.gif
#  extracting: data/train_masks/fa613ac8eac5_12_mask.gif
#  extracting: data/train_masks/fa613ac8eac5_13_mask.gif
#  extracting: data/train_masks/fa613ac8eac5_14_mask.gif
#  extracting: data/train_masks/fa613ac8eac5_15_mask.gif
#  extracting: data/train_masks/fa613ac8eac5_16_mask.gif
#  extracting: data/train_masks/fb1b923dd978_01_mask.gif
#  extracting: data/train_masks/fb1b923dd978_02_mask.gif
#  extracting: data/train_masks/fb1b923dd978_03_mask.gif
#  extracting: data/train_masks/fb1b923dd978_04_mask.gif
#  extracting: data/train_masks/fb1b923dd978_05_mask.gif
#  extracting: data/train_masks/fb1b923dd978_06_mask.gif
#  extracting: data/train_masks/fb1b923dd978_07_mask.gif
#  extracting: data/train_masks/fb1b923dd978_08_mask.gif
#  extracting: data/train_masks/fb1b923dd978_09_mask.gif
#  extracting: data/train_masks/fb1b923dd978_10_mask.gif
#   inflating: data/train_masks/fb1b923dd978_11_mask.gif
#  extracting: data/train_masks/fb1b923dd978_12_mask.gif
#  extracting: data/train_masks/fb1b923dd978_13_mask.gif
#  extracting: data/train_masks/fb1b923dd978_14_mask.gif
#  extracting: data/train_masks/fb1b923dd978_15_mask.gif
#  extracting: data/train_masks/fb1b923dd978_16_mask.gif
#  extracting: data/train_masks/fc237174b128_01_mask.gif
#   inflating: data/train_masks/fc237174b128_02_mask.gif
#  extracting: data/train_masks/fc237174b128_03_mask.gif
#  extracting: data/train_masks/fc237174b128_04_mask.gif
#   inflating: data/train_masks/fc237174b128_05_mask.gif
#  extracting: data/train_masks/fc237174b128_06_mask.gif
#   inflating: data/train_masks/fc237174b128_07_mask.gif
#  extracting: data/train_masks/fc237174b128_08_mask.gif
#  extracting: data/train_masks/fc237174b128_09_mask.gif
#  extracting: data/train_masks/fc237174b128_10_mask.gif
#  extracting: data/train_masks/fc237174b128_11_mask.gif
#  extracting: data/train_masks/fc237174b128_12_mask.gif
#   inflating: data/train_masks/fc237174b128_13_mask.gif
#  extracting: data/train_masks/fc237174b128_14_mask.gif
#  extracting: data/train_masks/fc237174b128_15_mask.gif
#  extracting: data/train_masks/fc237174b128_16_mask.gif
#  extracting: data/train_masks/fc5f1a3a66cf_01_mask.gif
#  extracting: data/train_masks/fc5f1a3a66cf_02_mask.gif
#  extracting: data/train_masks/fc5f1a3a66cf_03_mask.gif
#  extracting: data/train_masks/fc5f1a3a66cf_04_mask.gif
#  extracting: data/train_masks/fc5f1a3a66cf_05_mask.gif
#  extracting: data/train_masks/fc5f1a3a66cf_06_mask.gif
#  extracting: data/train_masks/fc5f1a3a66cf_07_mask.gif
#  extracting: data/train_masks/fc5f1a3a66cf_08_mask.gif
#  extracting: data/train_masks/fc5f1a3a66cf_09_mask.gif
#  extracting: data/train_masks/fc5f1a3a66cf_10_mask.gif
#  extracting: data/train_masks/fc5f1a3a66cf_11_mask.gif
#   inflating: data/train_masks/fc5f1a3a66cf_12_mask.gif
#  extracting: data/train_masks/fc5f1a3a66cf_13_mask.gif
#   inflating: data/train_masks/fc5f1a3a66cf_14_mask.gif
#  extracting: data/train_masks/fc5f1a3a66cf_15_mask.gif
#  extracting: data/train_masks/fc5f1a3a66cf_16_mask.gif
#  extracting: data/train_masks/fce0ba5b8ed7_01_mask.gif
#  extracting: data/train_masks/fce0ba5b8ed7_02_mask.gif
#  extracting: data/train_masks/fce0ba5b8ed7_03_mask.gif
#  extracting: data/train_masks/fce0ba5b8ed7_04_mask.gif
#  extracting: data/train_masks/fce0ba5b8ed7_05_mask.gif
#  extracting: data/train_masks/fce0ba5b8ed7_06_mask.gif
#  extracting: data/train_masks/fce0ba5b8ed7_07_mask.gif
#  extracting: data/train_masks/fce0ba5b8ed7_08_mask.gif
#  extracting: data/train_masks/fce0ba5b8ed7_09_mask.gif
#  extracting: data/train_masks/fce0ba5b8ed7_10_mask.gif
#   inflating: data/train_masks/fce0ba5b8ed7_11_mask.gif
#  extracting: data/train_masks/fce0ba5b8ed7_12_mask.gif
#  extracting: data/train_masks/fce0ba5b8ed7_13_mask.gif
#  extracting: data/train_masks/fce0ba5b8ed7_14_mask.gif
#  extracting: data/train_masks/fce0ba5b8ed7_15_mask.gif
#  extracting: data/train_masks/fce0ba5b8ed7_16_mask.gif
#  extracting: data/train_masks/fd9da5d0bb6f_01_mask.gif
#  extracting: data/train_masks/fd9da5d0bb6f_02_mask.gif
#  extracting: data/train_masks/fd9da5d0bb6f_03_mask.gif
#  extracting: data/train_masks/fd9da5d0bb6f_04_mask.gif
#  extracting: data/train_masks/fd9da5d0bb6f_05_mask.gif
#  extracting: data/train_masks/fd9da5d0bb6f_06_mask.gif
#  extracting: data/train_masks/fd9da5d0bb6f_07_mask.gif
#  extracting: data/train_masks/fd9da5d0bb6f_08_mask.gif
#  extracting: data/train_masks/fd9da5d0bb6f_09_mask.gif
#  extracting: data/train_masks/fd9da5d0bb6f_10_mask.gif
#  extracting: data/train_masks/fd9da5d0bb6f_11_mask.gif
#  extracting: data/train_masks/fd9da5d0bb6f_12_mask.gif
#  extracting: data/train_masks/fd9da5d0bb6f_13_mask.gif
#  extracting: data/train_masks/fd9da5d0bb6f_14_mask.gif
#  extracting: data/train_masks/fd9da5d0bb6f_15_mask.gif
#  extracting: data/train_masks/fd9da5d0bb6f_16_mask.gif
#  extracting: data/train_masks/fdc2c87853ce_01_mask.gif
#  extracting: data/train_masks/fdc2c87853ce_02_mask.gif
#  extracting: data/train_masks/fdc2c87853ce_03_mask.gif
#  extracting: data/train_masks/fdc2c87853ce_04_mask.gif
#  extracting: data/train_masks/fdc2c87853ce_05_mask.gif
#  extracting: data/train_masks/fdc2c87853ce_06_mask.gif
#  extracting: data/train_masks/fdc2c87853ce_07_mask.gif
#  extracting: data/train_masks/fdc2c87853ce_08_mask.gif
#  extracting: data/train_masks/fdc2c87853ce_09_mask.gif
#  extracting: data/train_masks/fdc2c87853ce_10_mask.gif
#  extracting: data/train_masks/fdc2c87853ce_11_mask.gif
#  extracting: data/train_masks/fdc2c87853ce_12_mask.gif
#  extracting: data/train_masks/fdc2c87853ce_13_mask.gif
#  extracting: data/train_masks/fdc2c87853ce_14_mask.gif
#  extracting: data/train_masks/fdc2c87853ce_15_mask.gif
#  extracting: data/train_masks/fdc2c87853ce_16_mask.gif
#  extracting: data/train_masks/feaf59172a01_01_mask.gif
#  extracting: data/train_masks/feaf59172a01_02_mask.gif
#   inflating: data/train_masks/feaf59172a01_03_mask.gif
#   inflating: data/train_masks/feaf59172a01_04_mask.gif
#  extracting: data/train_masks/feaf59172a01_05_mask.gif
#  extracting: data/train_masks/feaf59172a01_06_mask.gif
#   inflating: data/train_masks/feaf59172a01_07_mask.gif
#  extracting: data/train_masks/feaf59172a01_08_mask.gif
#  extracting: data/train_masks/feaf59172a01_09_mask.gif
#  extracting: data/train_masks/feaf59172a01_10_mask.gif
#  extracting: data/train_masks/feaf59172a01_11_mask.gif
#  extracting: data/train_masks/feaf59172a01_12_mask.gif
#  extracting: data/train_masks/feaf59172a01_13_mask.gif
#  extracting: data/train_masks/feaf59172a01_14_mask.gif
#   inflating: data/train_masks/feaf59172a01_15_mask.gif
#  extracting: data/train_masks/feaf59172a01_16_mask.gif
#  extracting: data/train_masks/fecea3036c59_01_mask.gif
#  extracting: data/train_masks/fecea3036c59_02_mask.gif
#  extracting: data/train_masks/fecea3036c59_03_mask.gif
#  extracting: data/train_masks/fecea3036c59_04_mask.gif
#  extracting: data/train_masks/fecea3036c59_05_mask.gif
#  extracting: data/train_masks/fecea3036c59_06_mask.gif
#  extracting: data/train_masks/fecea3036c59_07_mask.gif
#  extracting: data/train_masks/fecea3036c59_08_mask.gif
#  extracting: data/train_masks/fecea3036c59_09_mask.gif
#  extracting: data/train_masks/fecea3036c59_10_mask.gif
#  extracting: data/train_masks/fecea3036c59_11_mask.gif
#  extracting: data/train_masks/fecea3036c59_12_mask.gif
#  extracting: data/train_masks/fecea3036c59_13_mask.gif
#  extracting: data/train_masks/fecea3036c59_14_mask.gif
#  extracting: data/train_masks/fecea3036c59_15_mask.gif
#  extracting: data/train_masks/fecea3036c59_16_mask.gif
#   inflating: data/train_masks/fff9b3a5373f_01_mask.gif
#  extracting: data/train_masks/fff9b3a5373f_02_mask.gif
#  extracting: data/train_masks/fff9b3a5373f_03_mask.gif
#  extracting: data/train_masks/fff9b3a5373f_04_mask.gif
#  extracting: data/train_masks/fff9b3a5373f_05_mask.gif
#  extracting: data/train_masks/fff9b3a5373f_06_mask.gif
#  extracting: data/train_masks/fff9b3a5373f_07_mask.gif
#  extracting: data/train_masks/fff9b3a5373f_08_mask.gif
#  extracting: data/train_masks/fff9b3a5373f_09_mask.gif
#  extracting: data/train_masks/fff9b3a5373f_10_mask.gif
#  extracting: data/train_masks/fff9b3a5373f_11_mask.gif
#  extracting: data/train_masks/fff9b3a5373f_12_mask.gif
#  extracting: data/train_masks/fff9b3a5373f_13_mask.gif
#  extracting: data/train_masks/fff9b3a5373f_14_mask.gif
#  extracting: data/train_masks/fff9b3a5373f_15_mask.gif
#  extracting: data/train_masks/fff9b3a5373f_16_mask.gif

# %%
import os
import matplotlib.pyplot as plt
from PIL import Image
from torch.utils.data.dataset import Dataset
from torchvision import transforms

class CarvanaDataset(Dataset):
    def __init__(self, root_path, test=False):
        self.root_path = root_path
        if test:
            self.images = sorted([root_path+"/manual_test/"+i for i in os.listdir(root_path+"/manual_test/")])
            self.masks = sorted([root_path+"/manual_test_masks/"+i for i in os.listdir(root_path+"/manual_test_masks/")])
        else:
            self.images = sorted([root_path+"/train/"+i for i in os.listdir(root_path+"/train/")])
            self.masks = sorted([root_path+"/train_masks/"+i for i in os.listdir(root_path+"/train_masks/")])

        self.transform = transforms.Compose([
            transforms.Resize((512, 512)),
            transforms.ToTensor()])

    def __getitem__(self, index):
        img = Image.open(self.images[index]).convert("RGB")
        mask = Image.open(self.masks[index]).convert("L")

        return self.transform(img), self.transform(mask)

    def __len__(self):
        return len(self.images)

# %%
import torch
import torch.nn as nn

class DoubleConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv_op = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_channels, out_channels, kernel_size=3, padding=1),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.conv_op(x)


class DownSample(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.conv = DoubleConv(in_channels, out_channels)
        self.pool = nn.MaxPool2d(kernel_size=2, stride=2)

    def forward(self, x):
        down = self.conv(x)
        p = self.pool(down)

        return down, p


class UpSample(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.ConvTranspose2d(in_channels, in_channels//2, kernel_size=2, stride=2)
        self.conv = DoubleConv(in_channels, out_channels)

    def forward(self, x1, x2):
       x1 = self.up(x1)
       x = torch.cat([x1, x2], 1)
       return self.conv(x)

# %%
class UNet(nn.Module):
    def __init__(self, in_channels, num_classes):
        super().__init__()
        self.down_convolution_1 = DownSample(in_channels, 64)
        self.down_convolution_2 = DownSample(64, 128)
        self.down_convolution_3 = DownSample(128, 256)
        self.down_convolution_4 = DownSample(256, 512)

        self.bottle_neck = DoubleConv(512, 1024)

        self.up_convolution_1 = UpSample(1024, 512)
        self.up_convolution_2 = UpSample(512, 256)
        self.up_convolution_3 = UpSample(256, 128)
        self.up_convolution_4 = UpSample(128, 64)

        self.out = nn.Conv2d(in_channels=64, out_channels=num_classes, kernel_size=1)

    def forward(self, x):
       down_1, p1 = self.down_convolution_1(x)
       down_2, p2 = self.down_convolution_2(p1)
       down_3, p3 = self.down_convolution_3(p2)
       down_4, p4 = self.down_convolution_4(p3)

       b = self.bottle_neck(p4)

       up_1 = self.up_convolution_1(b, down_4)
       up_2 = self.up_convolution_2(up_1, down_3)
       up_3 = self.up_convolution_3(up_2, down_2)
       up_4 = self.up_convolution_4(up_3, down_1)

       out = self.out(up_4)
       return out

# %%
torch.cuda.empty_cache()

#print(torch.cuda.memory_usage())

# %%
import torch
from torch import optim, nn
from torch.utils.data import DataLoader, random_split
from tqdm import tqdm
if __name__ == "__main__":
    LEARNING_RATE = 3e-4
    BATCH_SIZE = 8
    EPOCHS = 1
    DATA_PATH = "/content/data"
    MODEL_SAVE_PATH = "/content/unet.pth"

    device = "cuda" if torch.cuda.is_available() else "cpu"
    train_dataset = CarvanaDataset(DATA_PATH)

    generator = torch.Generator().manual_seed(42)
    train_dataset, val_dataset = random_split(train_dataset, [0.8, 0.2], generator=generator)

    train_dataloader = DataLoader(dataset=train_dataset,
                                batch_size=BATCH_SIZE,
                                shuffle=True)
    val_dataloader = DataLoader(dataset=val_dataset,
                                batch_size=BATCH_SIZE,
                                shuffle=True)

    model = UNet(in_channels=3, num_classes=1).to(device)
    optimizer = optim.AdamW(model.parameters(), lr=LEARNING_RATE)
    criterion = nn.BCEWithLogitsLoss()

    for epoch in tqdm(range(EPOCHS)):
        model.train()
        train_running_loss = 0
        for idx, img_mask in enumerate(tqdm(train_dataloader)):
            img = img_mask[0].float().to(device)
            mask = img_mask[1].float().to(device)

            y_pred = model(img)
            optimizer.zero_grad()

            loss = criterion(y_pred, mask)
            train_running_loss += loss.item()

            loss.backward()
            optimizer.step()

        train_loss = train_running_loss / (idx + 1)

        model.eval()
        val_running_loss = 0
        with torch.no_grad():
            for idx, img_mask in enumerate(tqdm(val_dataloader)):
                img = img_mask[0].float().to(device)
                mask = img_mask[1].float().to(device)

                y_pred = model(img)
                loss = criterion(y_pred, mask)

                val_running_loss += loss.item()

            val_loss = val_running_loss / (idx + 1)

        print("-"*30)
        print(f"Train Loss EPOCH {epoch+1}: {train_loss:.4f}")
        print(f"Valid Loss EPOCH {epoch+1}: {val_loss:.4f}")
        print("-"*30)

    torch.save(model.state_dict(), MODEL_SAVE_PATH)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/509 [00:00<?, ?it/s]
#   0%|          | 1/509 [00:02<23:35,  2.79s/it]
#   0%|          | 2/509 [00:03<14:48,  1.75s/it]
#   1%|          | 3/509 [00:05<13:47,  1.63s/it]
#   1%|          | 4/509 [00:06<13:15,  1.58s/it]
#   1%|          | 5/509 [00:08<12:57,  1.54s/it]
#   1%|          | 6/509 [00:09<12:45,  1.52s/it]
#   1%|▏         | 7/509 [00:11<12:36,  1.51s/it]
#   2%|▏         | 8/509 [00:12<12:30,  1.50s/it]
#   2%|▏         | 9/509 [00:14<12:28,  1.50s/it]
#   2%|▏         | 10/509 [00:15<12:26,  1.50s/it]
#   2%|▏         | 11/509 [00:17<12:25,  1.50s/it]
#   2%|▏         | 12/509 [00:18<12:26,  1.50s/it]
#   3%|▎         | 13/509 [00:20<12:24,  1.50s/it]
#   3%|▎         | 14/509 [00:21<12:23,  1.50s/it]
#   3%|▎         | 15/509 [00:23<12:24,  1.51s/it]
#   3%|▎         | 16/509 [00:24<12:23,  1.51s/it]
#   3%|▎         | 17/509 [00:26<12:23,  1.51s/it]
#   4%|▎         | 18/509 [00:27<12:23,  1.51s/it]
#   4%|▎         | 19/509 [00:29<12:22,  1.52s/it]
#   4%|▍         | 20/509 [00:30<12:23,  1.52s/it]
#   4%|▍         | 21/509 [00:32<12:23,  1.52s/it]
#   4%|▍         | 22/509 [00:33<12:23,  1.53s/it]
#   5%|▍         | 23/509 [00:35<12:23,  1.53s/it]
#   5%|▍         | 24/509 [00:36<12:23,  1.53s/it]
#   5%|▍         | 25/509 [00:38<12:22,  1.53s/it]
#   5%|▌         | 26/509 [00:40<12:21,  1.54s/it]
#   5%|▌         | 27/509 [00:41<12:20,  1.54s/it]
#   6%|▌         | 28/509 [00:43<12:20,  1.54s/it]
#   6%|▌         | 29/509 [00:44<12:20,  1.54s/it]
#   6%|▌         | 30/509 [00:46<12:20,  1.55s/it]
#   6%|▌         | 31/509 [00:47<12:21,  1.55s/it]
#   6%|▋         | 32/509 [00:49<12:22,  1.56s/it]
#   6%|▋         | 33/509 [00:50<12:20,  1.56s/it]
#   7%|▋         | 34/509 [00:52<12:19,  1.56s/it]
#   7%|▋         | 35/509 [00:54<12:19,  1.56s/it]
#   7%|▋         | 36/509 [00:55<12:19,  1.56s/it]
#   7%|▋         | 37/509 [00:57<12:19,  1.57s/it]
#   7%|▋         | 38/509 [00:58<12:20,  1.57s/it]
#  88%|████████▊ | 450/509 [12:17<01:36,  1.64s/it]
#  89%|████████▊ | 451/509 [12:18<01:35,  1.64s/it]
#  89%|████████▉ | 452/509 [12:20<01:33,  1.64s/it]
#  89%|████████▉ | 453/509 [12:22<01:31,  1.64s/it]
#  89%|████████▉ | 454/509 [12:23<01:30,  1.64s/it]
#  89%|████████▉ | 455/509 [12:25<01:28,  1.64s/it]
#  90%|████████▉ | 456/509 [12:27<01:26,  1.64s/it]
#  90%|████████▉ | 457/509 [12:28<01:25,  1.64s/it]
#  90%|████████▉ | 458/509 [12:30<01:23,  1.64s/it]
#  90%|█████████ | 459/509 [12:31<01:21,  1.64s/it]
#  90%|█████████ | 460/509 [12:33<01:20,  1.64s/it]
#  91%|█████████ | 461/509 [12:35<01:18,  1.64s/it]
#  91%|█████████ | 462/509 [12:36<01:17,  1.64s/it]
#  91%|█████████ | 463/509 [12:38<01:15,  1.64s/it]
#  91%|█████████ | 464/509 [12:40<01:13,  1.64s/it]
#  91%|█████████▏| 465/509 [12:41<01:12,  1.64s/it]
#  92%|█████████▏| 466/509 [12:43<01:10,  1.64s/it]
#  92%|█████████▏| 467/509 [12:45<01:09,  1.64s/it]
#  92%|█████████▏| 468/509 [12:46<01:07,  1.64s/it]
#  92%|█████████▏| 469/509 [12:48<01:05,  1.64s/it]
#  92%|█████████▏| 470/509 [12:49<01:04,  1.64s/it]
#  93%|█████████▎| 471/509 [12:51<01:02,  1.64s/it]
#  93%|█████████▎| 472/509 [12:53<01:00,  1.64s/it]
#  93%|█████████▎| 473/509 [12:54<00:59,  1.64s/it]
#  93%|█████████▎| 474/509 [12:56<00:57,  1.64s/it]
#  93%|█████████▎| 475/509 [12:58<00:55,  1.64s/it]
#  94%|█████████▎| 476/509 [12:59<00:54,  1.64s/it]
#  94%|█████████▎| 477/509 [13:01<00:52,  1.64s/it]
#  94%|█████████▍| 478/509 [13:03<00:50,  1.64s/it]
#  94%|█████████▍| 479/509 [13:04<00:49,  1.64s/it]
#  94%|█████████▍| 480/509 [13:06<00:47,  1.64s/it]
#  94%|█████████▍| 481/509 [13:08<00:45,  1.64s/it]
#  95%|█████████▍| 482/509 [13:09<00:44,  1.64s/it]
#  95%|█████████▍| 483/509 [13:11<00:42,  1.64s/it]
#  95%|█████████▌| 484/509 [13:12<00:41,  1.64s/it]
#  95%|█████████▌| 485/509 [13:14<00:39,  1.64s/it]
#  95%|█████████▌| 486/509 [13:16<00:37,  1.64s/it]
#  96%|█████████▌| 487/509 [13:17<00:36,  1.65s/it]
#  96%|█████████▌| 488/509 [13:19<00:34,  1.65s/it]
#  96%|█████████▌| 489/509 [13:21<00:32,  1.65s/it]
#  96%|█████████▋| 490/509 [13:22<00:31,  1.65s/it]
#  96%|█████████▋| 491/509 [13:24<00:29,  1.65s/it]
#  97%|█████████▋| 492/509 [13:26<00:28,  1.65s/it]
#  97%|█████████▋| 493/509 [13:27<00:26,  1.65s/it]
#  95%|█████████▍| 121/128 [02:00<00:06,  1.03it/s]
#  95%|█████████▌| 122/128 [02:01<00:05,  1.03it/s]
#  96%|█████████▌| 123/128 [02:02<00:05,  1.03s/it]
#  97%|█████████▋| 124/128 [02:03<00:04,  1.07s/it]
#  98%|█████████▊| 125/128 [02:04<00:03,  1.04s/it]
#  98%|█████████▊| 126/128 [02:05<00:02,  1.02s/it]
#  99%|█████████▉| 127/128 [02:06<00:01,  1.00s/it]
# 100%|██████████| 128/128 [02:06<00:00,  1.01it/s]
# 100%|██████████| 1/1 [16:00<00:00, 960.74s/it]
# ------------------------------
# Train Loss EPOCH 1: 0.1357
# Valid Loss EPOCH 1: 0.0414
# ------------------------------

# %%
def pred_show_image_grid(data_path, model_pth, device):
    model = UNet(in_channels=3, num_classes=1).to(device)
    model.load_state_dict(torch.load(model_pth, map_location=torch.device(device)))
    image_dataset = CarvanaDataset(data_path, test=True)
    images = []
    orig_masks = []
    pred_masks = []

    for img, orig_mask in image_dataset:
        img = img.float().to(device)
        img = img.unsqueeze(0)

        pred_mask = model(img)

        img = img.squeeze(0).cpu().detach()
        img = img.permute(1, 2, 0)

        pred_mask = pred_mask.squeeze(0).cpu().detach()
        pred_mask = pred_mask.permute(1, 2, 0)
        pred_mask[pred_mask < 0] = 0
        pred_mask[pred_mask > 0] = 1

        orig_mask = orig_mask.cpu().detach()
        orig_mask = orig_mask.permute(1, 2, 0)

        images.append(img)
        orig_masks.append(orig_mask)
        pred_masks.append(pred_mask)

    images.extend(orig_masks)
    images.extend(pred_masks)
    fig = plt.figure(figsize=(10, 10))

    total_images = len(images)
    grid_size = 3
    for i in range(total_images):
        fig.add_subplot(grid_size, total_images // grid_size, i + 1)
        plt.imshow(images[i], cmap="gray")
        plt.axis('off')
    plt.show()


def single_image_inference(image_pth, model_pth, device):
    model = UNet(in_channels=3, num_classes=1).to(device)
    model.load_state_dict(torch.load(model_pth, map_location=torch.device(device)))

    transform = transforms.Compose([
        transforms.Resize((512, 512)),
        transforms.ToTensor()])

    img = transform(Image.open(image_pth)).float().to(device)
    img = img.unsqueeze(0)

    pred_mask = model(img)

    img = img.squeeze(0).cpu().detach()
    img = img.permute(1, 2, 0)

    pred_mask = pred_mask.squeeze(0).cpu().detach()
    pred_mask = pred_mask.permute(1, 2, 0)
    pred_mask[pred_mask < 0] = 0
    pred_mask[pred_mask > 0] = 1

    fig, axs = plt.subplots(1, 2, figsize=(10, 5))
    axs[0].imshow(img, cmap="gray")
    axs[0].set_title("Original Image")
    axs[0].axis('off')
    axs[1].imshow(pred_mask, cmap="gray")
    axs[1].set_title("Predicted Mask")
    axs[1].axis('off')
    plt.show()


if __name__ == "__main__":
    SINGLE_IMG_PATH = "./data/train/00087a6bd4dc_01.jpg"
    DATA_PATH = "./data"
    MODEL_PATH = "./unet.pth"

    device = "cuda" if torch.cuda.is_available() else "cpu"
    pred_show_image_grid(DATA_PATH, MODEL_PATH, device)
    single_image_inference(SINGLE_IMG_PATH, MODEL_PATH, device)
